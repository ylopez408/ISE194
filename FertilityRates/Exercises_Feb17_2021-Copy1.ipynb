# %% [markdown]
# # Data Load and Wrangle
#
# ## The goal of the exercise is to load a dataset, clean and transform and compute descriptive statistics

# %%
# This piece of code enables to display multiple output within a cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ## Task Instructions
# ### Load one of the built in dataset
# ### Transform the data as required
# ### From a perspective of a journalist interested in writing a story about the data, **_ask and answer_** **3** questions that summarize the sample.
#
# #### Please *_only use summary statistics_* (mean, median, mode, standard deviation, variance, range,..). The statistics can be computed by groups.
#
# #### Reference :https://kolesnikov.ga/Datasets_in_Python/
#
# </div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt
from scipy import stats

# %%
import statsmodels.api as sm
fertility = sm.datasets.fertility
print(fertility.DESCRLONG)
# Out:
# Total fertility rate represents the number of children that would be born to a woman if she were to live to the end of her childbearing years and bear children in accordance with current age-specific fertility rates.

# %%
print(fertility.NOTE)
# Out:
# ::
#
#     This is panel data in wide-format
#
#     Number of observations: 219
#     Number of variables: 58
#     Variable name definitions:
#         Country Name
#         Country Code
#         Indicator Name - The World Bank Series indicator
#         Indicator Code - The World Bank Series code
#         1960 - 2013 - The fertility rate for the given year

# %%
dataset_fertility = fertility.load_pandas()

# %%
df_fertility = pd.read_csv("FertilityRates.csv", skiprows = 2 )
#df_fertility.head()

# %%
df_fertility = dataset_fertility.data
df_fertility.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Fertility rate, total (births per woman)
# 1      Andorra          AND  Fertility rate, total (births per woman)
# 2  Afghanistan          AFG  Fertility rate, total (births per woman)
# 3       Angola          AGO  Fertility rate, total (births per woman)
# 4      Albania          ALB  Fertility rate, total (births per woman)
#
#    Indicator Code   1960   1961   1962   1963   1964   1965  ...   2004  \
# 0  SP.DYN.TFRT.IN  4.820  4.655  4.471  4.271  4.059  3.842  ...  1.786
# 1  SP.DYN.TFRT.IN    NaN    NaN    NaN    NaN    NaN    NaN  ...    NaN
# 2  SP.DYN.TFRT.IN  7.671  7.671  7.671  7.671  7.671  7.671  ...  7.136
# 3  SP.DYN.TFRT.IN  7.316  7.354  7.385  7.410  7.425  7.430  ...  6.704
# 4  SP.DYN.TFRT.IN  6.186  6.076  5.956  5.833  5.711  5.594  ...  2.004
#
#     2005   2006   2007   2008   2009   2010   2011  2012  2013
# ...

# %%
sm.datasets.fertility.load_pandas().data
# Out:
#          Country Name Country Code                            Indicator Name  \
# 0               Aruba          ABW  Fertility rate, total (births per woman)
# 1             Andorra          AND  Fertility rate, total (births per woman)
# 2         Afghanistan          AFG  Fertility rate, total (births per woman)
# 3              Angola          AGO  Fertility rate, total (births per woman)
# 4             Albania          ALB  Fertility rate, total (births per woman)
# ..                ...          ...                                       ...
# 214       Yemen, Rep.          YEM  Fertility rate, total (births per woman)
# 215      South Africa          ZAF  Fertility rate, total (births per woman)
# 216  Congo, Dem. Rep.          COD  Fertility rate, total (births per woman)
# 217            Zambia          ZMB  Fertility rate, total (births per woman)
# 218          Zimbabwe          ZWE  Fertility rate, total (births per woman)
#
# ...

# %%
df_fertility.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 58 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    219 non-null    object
#  1   Country Code    219 non-null    object
#  2   Indicator Name  219 non-null    object
#  3   Indicator Code  219 non-null    object
#  4   1960            194 non-null    float64
#  5   1961            195 non-null    float64
#  6   1962            194 non-null    float64
#  7   1963            193 non-null    float64
#  8   1964            194 non-null    float64
#  9   1965            194 non-null    float64
#  10  1966            194 non-null    float64
#  11  1967            194 non-null    float64
#  12  1968            194 non-null    float64
#  13  1969            194 non-null    float64
#  14  1970            194 non-null    float64
#  15  1971            195 non-null    float64
#  16  1972            196 non-null    float64
# ...

# %%
mean1 = df_fertility['1960'].mean()
max1 = df_fertility['1998'].max()
std1 = df_fertility['2005'].std()

# %%
print("What is the mean of fertility rates in 1960?")
print('Mean rate:'+str(mean1))
# Out:
# What is the mean of fertility rates in 1960?
# Mean rate:5.511814432989688

# %%
print("What is the max fertility rate in 1998?")
print('Max rate:'+str(max1))
# Out:
# What is the max fertility rate in 1998?
# Max rate:7.854

# %%
print("What is the standard deviation of fertility rates in 2005?")
print('Standard deviation:'+str(std1))
# Out:
# What is the standard deviation of fertility rates in 2005?
# Standard deviation:1.6240432463994556

# %%
CountryName = df_fertility["Country Name"]
CountryName.head()
# Out:
# 0          Aruba
# 1        Andorra
# 2    Afghanistan
# 3         Angola
# 4        Albania
# Name: Country Name, dtype: object

# %%
CountryName_1998 = df_fertility[["Country Name","1998"]]
CountryName_1998.head()
# Out:
#   Country Name   1998
# 0        Aruba  1.940
# 1      Andorra    NaN
# 2  Afghanistan  7.854
# 3       Angola  6.913
# 4      Albania  2.543

# %%
##Aruba = df_fertility[df_fertility["Country Name"].isin

# %%
df_fertility.iloc[0:1,42:43]
# Out:
#    1998
# 0  1.94

# %%
df_fertility[['Country Name',"1998"]].plot.hist(bins=20, alpha=0.5)
plt.title('Fertility Rates Countries in 1998')
plt.xlabel("Fertility Rates")
# Out:
# <AxesSubplot:ylabel='Frequency'>
# Text(0.5, 1.0, 'Fertility Rates Countries in 1998')
# Text(0.5, 0, 'Fertility Rates')

# %%
stats.probplot(df_fertility['2005'], plot=plt)
fig = plt.figure()
res = stats.probplot(df_fertility['2005'],plot=plt)
plt.ylabel('2005 Fertility Rates')
plt.show()
# Out:
# ((array([-2.73069442, -2.42425735, -2.24987384, -2.12514902, -2.02671659,
#          -1.94472048, -1.87403316, -1.81163199, -1.7555791 , -1.70455458,
#          -1.65761721, -1.61407123, -1.57338714, -1.53515228, -1.49903847,
#          -1.46478027, -1.43215977, -1.40099581, -1.37113604, -1.3424511 ,
#          -1.31483013, -1.28817738, -1.26240956, -1.23745375, -1.21324569,
#          -1.18972849, -1.16685149, -1.1445694 , -1.12284154, -1.10163124,
#          -1.08090529, -1.06063354, -1.04078855, -1.02134519, -1.00228048,
#          -0.98357327, -0.9652041 , -0.94715496, -0.92940923, -0.91195146,
#          -0.8947673 , -0.87784338, -0.86116723, -0.8447272 , -0.82851237,
#          -0.8125125 , -0.79671797, -0.78111975, -0.7657093 , -0.75047858,
#          -0.73542001, -0.72052638, -0.70579089, -0.69120708, -0.67676883,
#          -0.6624703 , -0.64830594, -0.63427049, -0.62035888, -0.60656631,
#          -0.59288818, -0.57932009, -0.56585782, -0.55249733, -0.53923475,
# ...

# %%
yax = df_fertility.groupby(['1990'])['2000'].mean()
plt.barh(yax.index, yax)
plt.title('Fertility rates across countries in 1990 and 2000')
# Out:
# <BarContainer object of 189 artists>
# Text(0.5, 1.0, 'Fertility rates across countries in 1990 and 2000')

# %%
print("Variables: Country Name, Country Code, Year")
print("Fertility Rates dramatically decreases across all countries from the years 1960  to 2005.")
print("In the year 1998, most fertility rates ranged between 1.0 and 2.0 throughout the different countries.")
# Out:
# Variables: Country Name, Country Code, Year
# Fertility Rates dramatically decreases across all countries from the years 1960  to 2005.
# In the year 1998, most fertility rates ranged between 1.0 and 2.0 throughout the different countries.

# %%
subsetd = df_fertility[['Country Name', '1998','2010']]

# %%
from pandas import Series, DataFrame

# %%
from scipy.stats import shapiro
series_2test = df_fertility[['1998']]
stat, p = shapiro(series_2test)
print('stat=%.3f, p=%.3f' % (stat,p))
if p > 0.05:
    print('Probably Gaussian')
else:
    print('Probably not Gaussian')
# Out:
# stat=nan, p=1.000
# Probably Gaussian

# %%
df_fertility_ts = pd.DataFrame(df_fertility.groupby(['1998']).count())
df_fertility_ts.info()
df_fertility_ts.head()
df_fertility_ts.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 186 entries, 1.017 to 7.854
# Data columns (total 57 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    186 non-null    int64
#  1   Country Code    186 non-null    int64
#  2   Indicator Name  186 non-null    int64
#  3   Indicator Code  186 non-null    int64
#  4   1960            186 non-null    int64
#  5   1961            186 non-null    int64
#  6   1962            186 non-null    int64
#  7   1963            186 non-null    int64
#  8   1964            186 non-null    int64
#  9   1965            186 non-null    int64
#  10  1966            186 non-null    int64
#  11  1967            186 non-null    int64
#  12  1968            186 non-null    int64
#  13  1969            186 non-null    int64
#  14  1970            186 non-null    int64
#  15  1971            186 non-null    int64
#  16  1972            186 non-null    int64
# ...

# %%
df_fertility.drop(['Country Code','Indicator Code', 'Indicator Name'], axis = 1, inplace = True)
df_pivoted = df_fertility.melt(id_vars=["Country Name"], 
        var_name="Year", 
        value_name="Fertilityrate")
df_pivoted.head()
# Out:
#   Country Name  Year  Fertilityrate
# 0        Aruba  1960          4.820
# 1      Andorra  1960            NaN
# 2  Afghanistan  1960          7.671
# 3       Angola  1960          7.316
# 4      Albania  1960          6.186

# %%
df_pivoted.describe()
# Out:
#        Fertilityrate
# count   10284.000000
# mean        4.178901
# std         2.031078
# min         0.836000
# 25%         2.260000
# 50%         3.963000
# 75%         6.099000
# max         9.223000

# %%
df_pivoted['Country Name'].value_counts()
# Out:
# Romania                  54
# Virgin Islands (U.S.)    54
# Austria                  54
# Bahamas, The             54
# Antigua and Barbuda      54
#                          ..
# Dominica                 54
# Germany                  54
# Cayman Islands           54
# Syrian Arab Republic     54
# Jamaica                  54
# Name: Country Name, Length: 219, dtype: int64

# %%
df_pivoted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11826 entries, 0 to 11825
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   11826 non-null  object
#  1   Year           11826 non-null  object
#  2   Fertilityrate  10284 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 277.3+ KB

# %%
working_data = df_pivoted.copy()

# %%
from datetime import date
date_sold = pd.DataFrame({'year': working_data['Year']})
date_sold.shape
# Out:
# (11826, 1)

# %%
subset_data = working_data[['Country Name','Fertilityrate','Year']]

# %%
subset_data.shape
subset_data.isnull().sum()[subset_data.isnull().sum()>0].sort_values(ascending=False)
subset_data.dropna()
subset_data_nomiss = subset_data.dropna()
subset_data_nomiss.shape
# Out:
# (11826, 2)
# Fertilityrate    1542
# dtype: int64
#        Fertilityrate  Year
# 0              4.820  1960
# 2              7.671  1960
# 3              7.316  1960
# 4              6.186  1960
# 5              6.928  1960
# ...              ...   ...
# 11383          4.348  2011
# 11384          2.438  2011
# 11385          6.146  2011
# 11386          5.773  2011
# 11387          3.643  2011
#
# [10284 rows x 2 columns]
# (10284, 2)

# %%
#for i in range(1, len(dataset)): # specifying 1 here will skip the first row
    #dataset[i] = [float(x) for x in dataset[i]

# %%
#data = subset_data
#data = data.set_index('Country Name')
#data = data.drop('Country Name', axis=0)

# %%
del subset_data['Country Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-f8cd841cf8f9> in <module>
# ...

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib import pyplot
series = subset_data
results = seasonal_decompose(series, model='additive')
results.plot()
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-de9a21a55db6> in <module>
#       2 from matplotlib import pyplot
#       3 series = subset_data
# ----> 4 results = seasonal_decompose(series, model='additive')
#       5 results.plot()
#       6 pyplot.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/seasonal.py in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     129
#     130     if not np.all(np.isfinite(x)):
# --> 131         raise ValueError("This function does not handle missing values")
# ...

# %%
import operator
from statsmodels.tsa.seasonal import STL
if df_fertility.loc[df_fertility['Country Name'].isin(['1998','2005'])].any():
    stl = STL(pd.Series(df_fertility_ts),period = 56)
    res = stl.fit()
    fig = res.plot()
#if((df_fertility[col] == ' this is any string or list').any()):
#return(df.loc[df[col] == temp].index.values.astype(int)[57])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-572f8b8120cc> in <module>
#       1 import operator
#       2 from statsmodels.tsa.seasonal import STL
# ----> 3 if df_fertility.loc[df_fertility['Country Name'].isin(['1998','2005'])].any():
#       4     stl = STL(pd.Series(df_fertility_ts),period = 56)
#       5     res = stl.fit()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
